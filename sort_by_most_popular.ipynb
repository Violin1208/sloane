# %%
import pandas as pd
import re

# %%
path = 'underlined.csv'

# %%
pat = re.compile('.*#(.*)\'\]')

# %%
df = pd.read_csv(path)

# %%
len(df)
# Out:
# 3947

# %%
df[df.person != '[]']
# Out:
#       Unnamed: 0    catnum                                         underline  \
# 0              0  ['1799']                                 ['bow', 'Amyand']
# 2              2  ['1801']                          ['trumpet', 'Theobalds']
# 7              7  ['1806']                             ['glasse', 'Roberts']
# 8              8  ['1807']                                       ['Cormick']
# 10            10  ['1809']                     ['weapon', 'horns', 'Stuart']
# ...          ...       ...                                               ...
# 3850        3850   ['205']  ['dagger', 'haft', 'Capis nephritieus', 'Waldo']
# 3865        3865   ['220']                  ['Buttons', 'Cornelian', 'Bell']
# 3872        3872   ['227']                   ['mortar', 'porphyry', 'Ranby']
# 3874        3874   ['229']                       ['agate Spoon', 'Shepherd']
# 3946        3946   ['302']          ['Amethyst', 'snuff box', 'Montmorency']
#
#                              label         xml_id                     person  \
# 0                    Miscellanies.  EPF108491002v            ['#Mr._Amyand']
# 2                    Miscellanies.  EPF108491002v  ['#James_Theobalds_Esqr']
# 7                    Miscellanies.  EPF108491002v            ['#Mr_Roberts']
# 8                    Miscellanies.  EPF108491002v                  ['#MrMC']
# 10                   Miscellanies.  EPF108491002v      ['#Alexander_Stuart']
# ...                            ...            ...                        ...
# 3850  Agate cups botles spoons &c.   EPF108491326          ['#Daniel_Waldo']
# 3865  Agate cups botles spoons &c.   EPF108491327              ['#Mr._Bell']
# 3872  Agate cups botles spoons &c.   EPF108491327            ['#John_Ranby']
# 3874  Agate cups botles spoons &c.   EPF108491327          ['#Mrs_Shepherd']
# 3946  Agate cups botles spoons &c.   EPF108491329     ['#Madam_Montmorency']
#
#      place
# 0       []
# 2       []
# 7       []
# 8       []
# 10      []
# ...    ...
# 3850    []
# 3865    []
# 3872    []
# 3874    []
# 3946    []
#
# [729 rows x 7 columns]

# %%
len(df[df.person != '[]'])
# Out:
# 729

# %%
len(df.person.unique())
# Out:
# 407

# %%
names = df.person

# %%
names_unique = df.person.unique()

# %%
for name in names:
    if 'james' in name.lower():
        print(name)
# Out:
# ['#James_Theobalds_Esqr']
# ['#James_Cunningham']
# ['#James_Petiver']
# ['#James_Wilson']
# ['#James_Cunningham', '#James_Cunningham']
# ['#Mr_James']
# ['#Joy', '#James_Petiver']
# ['#George_Harris', '#James_Petiver']
# ['#James_Petiver', '#Mr_Walduck', '#James_Petiver']
# ['#Paul_Lucas', '#Charles_Lennox_Duke_of_Richmond, James_Stuart_Duke_of_Richmond']
# ['#James_Hodgson']
# ['#King_James']
# ['#King_James_2nd']
# ['# James_Stanier']
# ['#Charles_Lennox_Duke_of_Richmond, James_Stuart_Duke_of_Richmond']
# ['#James_Petiver', '#William_Faithorne']

# %%
name = '['#George_Edwards, Mr._Edwards']'

# %%
res = set()
for x in names_unique:
    n = eval(x)
#     print(n)
    if n:
        for i in n:
            print(i.strip('#'))
            res.add(i.strip('#'))

# %%
len(res)
# Out:
# 427

# %%
res

# %%
d_count = {}
for n in res:
    count = df['person'].str.contains(n).sum()
#     print(n + 'count:' + str(count))
    d_count[n] = count

# %%
d_count
# Out:
# {'Mr._Amyand': 1,
#  'James_Theobalds_Esqr': 3,
#  'Mr_Roberts': 3,
#  'MrMC': 2,
#  'Alexander_Stuart': 4,
#  'Mr._Hodson': 2,
#  'Mr._Launce': 1,
#  'Jean_De_Fontaney': 5,
#  'James_Cunningham': 4,
#  'Daniel_Waldo': 15,
#  'Capt_Walker': 2,
#  'Isaac_Waldron_Esqr': 1,
#  'Abraham_Waldron': 1,
#  'William_Courten': 7,
#  'George_Edwards, Mr._Edwards': 4,
#  'Richard_Middleton_Massey': 7,
#  'Peter_Collinson': 2,
#  'Matthew_Gosset': 1,
#  'Mr._Gordon': 2,
#  'Dr_Douce': 2,
#  'Duke_of_Bourbon': 1,
#  'Mrs_Edwards, Mrs._Edwards': 1,
#  'Lady_Sondes': 1,
#  'Mr_Styleman': 1,
#  'Mr._Bell': 9,
#  'Capt_Christopher_Middleton': 1,
#  'Mr_Hoofnail': 1,
#  'Mrs_Hepheshebah_Parker': 1,
#  'Dr_Labe': 1,
#  'Mrs_Stephens': 1,
#  'James_Petiver': 33,
#  'Mr._Pycolas': 1,
#  'Moses': 1,
#  'Mr_Collier': 1,
#  'Mrs_Bernard': 1,
#  'Mrs_Hayes': 3,
#  'Mr_Lapthorn': 2,
#  'Mr_Doyly': 1,
#  'Mr._Bewley': 1,
#  'Rene_Reaumur': 2,
#  'Francois_Duquesnoy': 1,
#  'Mr._Beddevoles': 1,
#  'Mr._Marshall': 2,
#  'James_Wilson': 5,
#  'John_Melling': 1,
#  'Johannes_van_Musschenbroek': 1,
#  'King3': 3,
#  'Mr_Desmarets': 1,
#  'Francis_Hauksbee': 1,
#  'Arthur_Charlett': 1,
#  'John_Pinfold': 4,
#  'Giuseppe_Campani': 1,
#  'Mr_Lenoy': 1,
#  'Stephen_Gray': 1,
#  'Gio_Bapt_Verle': 1,
#  'Mr_Villarmont': 1,
#  'Robert_Hooke': 8,
#  'Patrick_Adair': 5,
#  'Mr_Maidstone, Mr._Maidstone': 8,
#  'Frederick_Slare': 2,
#  'John_Conyers': 8,
#  'Robert_Boyle': 2,
#  'William_von_Schroder': 1,
#  'Robert_Moray': 1,
#  'Lord_Colerane': 1,
#  'Monsr_Villette': 1,
#  'Pierre_Silvestre': 2,
#  'Mr._Staphorst': 1,
#  'Father_Visdelon': 1,
#  'Beauvilliers': 1,
#  'Lady_Kent': 1,
#  'Mr_Carmichael': 1,
#  'William_Sherard': 1,
#  'Charles_Leigh': 1,
#  'Dampier': 2,
#  'Charles_Montagu': 1,
#  'Duke_Marlborough': 2,
#  'Mr_Robert_Walker': 1,
#  'Colonel_Laws': 1,
#  'Mrs_Sadler': 1,
#  'Mr_Orchard': 1,
#  'Edmund_Chishull': 1,
#  'Mr_Middleton': 1,
#  'Sir_Charles_Wager': 1,
#  'Richard_Mead': 1,
#  'Alexander_Brown': 11,
#  'Dr._Brown': 48,
#  'Hoffsted_van_Essen': 2,
#  'Mrrown': 1,
#  'Dr_Browne': 1,
#  'George_Cheyne': 1,
#  'Dr_Groenfield': 1,
#  'Mr_Hodges': 2,
#  'Mr_James': 1,
#  'Ambrose_Godfrey-Hanckwitz': 3,
#  'Joy': 2,
#  'William_Dunker': 1,
#  'John_Rawdon': 1,
#  'Martha_Cooper': 1,
#  'Sr_Streynsham_Masters': 1,
#  'Thomas_Tennison': 2,
#  'Duke_of_Monmouth': 1,
#  'Caspar_Antonio': 2,
#  'Dr._Hobbs': 1,
#  'Mr._Homberg': 1,
#  'Claude_Geoffroy1': 2,
#  'Mr._Robinson': 1,
#  'Gilbert_Heathcote': 4,
#  'Jean_Rodoplhe_Lavater, Dr._Lavater': 3,
#  'Mr_Burnett': 1,
#  'Mr._Cowper': 6,
#  'Francis_Aston': 1,
#  'Jean_Rodolphe_Perronet': 1,
#  'Mr_Gilberts': 1,
#  'Martin_Lister': 5,
#  'William_Cowper2': 1,
#  'Robert_Harley': 1,
#  'Albertus_Seba': 1,
#  'Johann_Georg_Steigertahl': 4,
#  'Mrs._Trenchfield': 1,
#  'Mr._Moults': 1,
#  'Mr_Stallwood': 1,
#  'Mr_Johnson': 1,
#  'Mr._Ott': 1,
#  'Charles_Cadogan': 2,
#  'Thomas_Simon': 3,
#  'Riley': 1,
#  'Mrs_Byde': 1,
#  'George_Harris': 1,
#  'Prince_of_Hesse': 1,
#  'John_Conduitt': 1,
#  'Baron_Botmar': 1,
#  'Dr_Bokelman': 2,
#  'Mrs_Heathcote': 1,
#  'Mr._Serocold': 1,
#  'HenrySr.': 2,
#  'Elihu_Yale': 4,
#  'Mr_Van_Mildert': 3,
#  'Mr_Harvey': 1,
#  'Dr._Kempfer': 8,
#  'Abraham_Cyprianus': 4,
#  'Mr._Hill': 1,
#  'Mr_Dupuys': 6,
#  'John_Covel': 5,
#  'Mrs_Astall': 1,
#  'George_I': 2,
#  'Lady_Darlington': 1,
#  'Benjamin_Franklin': 2,
#  'Mark_Catesby': 1,
#  'Francis_Nicholson': 2,
#  'Robert_Houston': 2,
#  'Nicolas_Waites': 1,
#  'JohnFul': 3,
#  'Mr._Campbell': 1,
#  'Roger_Gale': 3,
#  'Baron_Rostgard': 1,
#  'Mr_Skinner': 1,
#  'Charles_Lockyer': 1,
#  'Dr_Hubbert': 1,
#  'Mr_Elking': 2,
#  'Thomas_Pitt': 1,
#  'Mr._Harris': 1,
#  'Dr_Burnett': 1,
#  'Dr_Hoffman': 1,
#  'Henry_Plumptre': 1,
#  'Mr_John_Heathcote': 1,
#  'Mrs_Shepherd': 2,
#  'Mr._Clerk': 3,
#  'Mrs_Dering, Mrs._Dering': 3,
#  'Governor_Bennet': 1,
#  'Dr_Varin': 1,
#  'Mr_Fabre': 1,
#  'Mr_Padmore': 1,
#  'Mr_Lyell': 1,
#  'D_Woodward': 7,
#  'Mr_Walduck': 1,
#  'Mr_Standish': 1,
#  'John_Ranby': 5,
#  'Mr._Barrets': 1,
#  'Mr._Dering': 4,
#  'Mr_Maidstone': 9,
#  'Robert_Southwell': 1,
#  'Mr_Purnell': 2,
#  'John_Thomas_Woolhouse': 1,
#  'Dr._Mausafia': 1,
#  'Dr_Battely': 1,
#  'Mr_Nichols': 1,
#  'Mrs_Steigertahl': 1,
#  'Paul_Lucas': 1,
#  'Charles_Lennox_Duke_of_Richmond, James_Stuart_Duke_of_Richmond': 2,
#  'Mr._Wild': 1,
#  'Governr_Jennings': 1,
#  'Erik_Benzelius': 1,
#  'William_Houstoun': 1,
#  'Thomas_Short': 4,
#  'Mr._Bradley': 1,
#  'Mr_Talbot': 1,
#  'Isaaci_Barrow': 1,
#  'Dr._Clifton': 1,
#  'Nehemiah_Grew': 2,
#  'Mr._Godfroy': 1,
#  'Mr._Graham': 1,
#  'Mr_Lascelles': 1,
#  'Mr._Kenly': 1,
#  'Abbe_Bernardo_Sterbini': 5,
#  'Henry_Newman': 1,
#  'Peirce_Dod': 1,
#  'Mrs_Marshall': 1,
#  'Mr_Nash': 1,
#  'Mr_Sainthill': 1,
#  'Revd_Mr_Scott': 1,
#  'Charles_Maitland': 1,
#  'FrancisBuccleuch': 1,
#  'Mr_Green': 2,
#  'Mr_Gilbert': 2,
#  'Mr_Muhleman': 1,
#  'John_Winthrop': 5,
#  'John_Winthrop, Mr._Winthorpe': 1,
#  'James_Hodgson': 1,
#  'Johann_Amman': 1,
#  'Capt_Jenkens': 1,
#  'Queen_Elizabeth_I': 3,
#  'Mr._Laurie': 2,
#  'Philip_Miller': 1,
#  'Mr._Mason': 1,
#  'Mr_Seguier': 2,
#  'Mr_Grubb': 1,
#  'Mr._Cox': 1,
#  'Cardinal_Gualtieri': 14,
#  'Johann_Jakob_Scheuchzer': 1,
#  'Mr_Cooke': 9,
#  'Dr_Huntington': 2,
#  'Mr._Compton': 2,
#  'Mr_Charles_de_la_Fontaine': 1,
#  'Mr_Conyers': 1,
#  'Oldsworth': 1,
#  'Dr_John_Harwood, Dr_Harwood': 1,
#  'King_James': 3,
#  'Richard_Richardson': 2,
#  'Mr._Martin': 1,
#  'John_Morton': 5,
#  'Thomas_Browne': 2,
#  'Oldisworth': 2,
#  'Mr._Sandys': 1,
#  'Edward_Browne': 1,
#  'Mr_Lloyd': 1,
#  'Mr_Cairns': 1,
#  'Bp_of_Norwich': 1,
#  'Charles_Townshend': 1,
#  'Mr._Wainwright': 1,
#  'Jius': 1,
#  'Mr_Holiday': 1,
#  'Adrian_Beverland': 2,
#  'Dr_Brooks': 1,
#  'John_Kempe': 11,
#  'William_Ellis': 1,
#  'Mr_Alexander_Gordon': 1,
#  'Mr_Kennedy': 1,
#  'Mr._Smith': 1,
#  'Mr_Warner_': 3,
#  'Lord_Burlington': 1,
#  'Andr_Hay': 1,
#  'William_Stukely': 2,
#  'Mr._Stanley': 1,
#  'Sr._John_Colbatch': 1,
#  'Mr_Hildesley': 1,
#  'Robert_Wood': 1,
#  'Mrs_Standish': 1,
#  'Lord_Pembroke': 1,
#  'Mr_George': 1,
#  'Soranzo': 1,
#  'Mr._Nadler': 2,
#  'Cromwell_Mortimer': 1,
#  'Mr_Leneve': 2,
#  'Dr._Rosse': 1,
#  'Mr_Jackson': 1,
#  'Oliver_Cromwell': 5,
#  'Francois_Louis_de_Bourbon': 1,
#  'William_Courtney': 1,
#  'Henry_ye_8th': 3,
#  'Isaac_Newton': 1,
#  'King_James_2nd': 2,
#  'Doge_Francesco_Morosini': 1,
#  'Louis_14th': 1,
#  'Sir_Richard_Steele': 2,
#  'Duke_of_Bavaria': 1,
#  'Francis_Drake': 1,
#  'Sir_Edward_Nicholas': 1,
#  'Albert_Durer': 3,
#  'David_Loggan': 2,
#  'T_Dackett': 1,
#  'Mrs._Pritchard': 1,
#  'Mrs._Merian': 5,
#  'Nicolas_Robert': 3,
#  'William_Faithorne': 3,
#  'Guilllaume_Toulouze': 6,
#  'Richard_Hooker': 1,
#  'Laurentius_Costerus': 1,
#  'Bernard_Lens_II': 1,
#  'Mr._Bizot': 1,
#  'Orlando_Bridgeman': 1,
#  'Mr._Petyt': 1,
#  'Mr._Doyly': 2,
#  'Du_Bosse': 1,
#  'George_Duke_Albemarle': 1,
#  'Della_Bella': 1,
#  'Margaret_Smith': 1,
#  'John_Caius': 1,
#  'Samuel_Pepys': 1,
#  ' James_Stanier': 1,
#  'Mrs._Johanna_Byron': 1,
#  'Barlow': 1,
#  'Mr._Jacob_Selo': 1,
#  'Alexander_Marshal': 1,
#  'William_Harvey': 1,
#  'Mrs_Fuller': 2,
#  'Jeremiah_Taverner': 2,
#  'Mr._Sam._Langley': 2,
#  'Wissen': 1,
#  'Rossi': 1,
#  'Mrs_Courten': 1,
#  'Van_Dyck': 2,
#  'John_Cecil_5th_Earl_of_Exeter': 1,
#  'Silvestre': 3,
#  'Mrs._Anne_Rose': 1,
#  'Hans_Holbein': 3,
#  'Miller': 2,
#  'Vesalius': 1,
#  'Antony_More': 1,
#  'Franciscus_Mercurius_van_Vanhelmont': 1,
#  'Thomas_Murray': 7,
#  'Joos_de_Momper': 1,
#  'Sr_Theodore_Mayern': 1,
#  'Philip_Rose, Fulke-Rose': 1,
#  'Mrs._Willoughby': 1,
#  'Peter_Paul_Rubens': 1,
#  'Polemburg': 1,
#  'Hans_Sloane': 1,
#  'Mrs_Sloane': 1,
#  'Ulisse_Aldrovandi': 1,
#  'Giorgione': 1,
#  'Mr_Cock': 1,
#  'Edmund_King': 1,
#  'Housman': 1,
#  'Mr_Kinsay': 1,
#  'HE': 1,
#  'Martin_Luther': 1,
#  'Earl_of_Arundell': 1,
#  'Thomas_Browne, Thomas_Browne': 1,
#  'Owen_Brigstocke': 1,
#  'George_Jeffreys': 1,
#  'Frere_Jaques': 1,
#  'Adriaen_Brouwer': 1,
#  'Mr._Hughs': 2,
#  'Charles_I': 5,
#  'Anna_Maria_van_Schurman': 2,
#  'William_Dobson': 1,
#  'Hilliard': 1,
#  'Mr_Thornton': 1,
#  'Frederik_Ruysch': 1,
#  'Mrs_Aesop': 1,
#  'Francesco_Cornaro': 1,
#  'Frederich_Saxony': 1,
#  'Earl_of_Essex': 1,
#  'Jacomo_Poro': 1,
#  'Barbara_van_Beck': 1,
#  'Philip_2nd_of_Spain': 1,
#  'John_Oliver, Olivar': 1,
#  'Sir_Thomas_More': 1,
#  'John_Fisher': 1,
#  'Thomas_Gresham': 1,
#  'Abraham_Simon': 1,
#  ' Fielder_the_Vintner': 1,
#  'John_Oliver': 2,
#  'Charles_II': 2,
#  'Giovanni_Maria_Lancisi': 1,
#  'Sebastiano_Concha': 1,
#  'Queen_Anne': 1,
#  'Mr._Dundasse': 1,
#  'George_II': 1,
#  'William_Duke_of_Gloucester': 1,
#  'Valerius_Bellus': 2,
#  'Richard_Baker': 1,
#  'Jacques_Callot': 2,
#  'Moliere': 1,
#  'Pierre_Corneille': 1,
#  'Charles_Derby': 1,
#  'Jean_de_Labadie': 1,
#  'John_Fletcher': 1,
#  'Polidoro_di_Caravagio': 1,
#  'Mr._Simpson': 1,
#  'Lord_Archbishop_Dublin': 1,
#  'Frank_van_Borselen': 1,
#  'Philip_Wouwerman': 1,
#  'Tobias_Stranover': 1,
#  'Lord_Lynn': 1,
#  'Jan_van-Huysum': 1,
#  'Queen_Catherine': 2,
#  'Gilbert_Burnett': 1,
#  'Vanzoon': 1,
#  'Lord_Yarmouth': 1,
#  'J._Simmons': 1,
#  'Dr._Rugeley_father': 1,
#  'Mr_Jones': 1,
#  'Dr._Rugeley': 2,
#  'Major_John_Hanbury': 1,
#  'Sr_Godfrey_Kneller': 2,
#  'Alexander_Geekie_senior': 1,
#  'Mrs_John_Hanbury': 1,
#  'Walter_Churchman': 1,
#  'Jacob_Theodor_Klein': 1,
#  'Guillaume_Dupre': 1,
#  'Godwin_Lewis': 1,
#  'Mr._Butterfield': 3,
#  'Eustachio_de_divinis': 1,
#  'Charles_Scarburgh': 1,
#  'Edward_Baynard': 1,
#  'Colonel_Wharton': 1,
#  'Henry_Wynne': 1,
#  'Christophe_Albemarle': 2,
#  'Johann_Ernst_Galliard': 1,
#  'William_Nicholson': 1,
#  'Mr._Thomas': 1,
#  'Mr_Vanhulse': 1,
#  'Mr._Marlow': 5,
#  'Mr._Tinsey': 1,
#  'Madam_Montmorency': 1}

# %%
dict(sorted(d_count.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'Dr._Brown': 48,
#  'James_Petiver': 33,
#  'Daniel_Waldo': 15,
#  'Cardinal_Gualtieri': 14,
#  'Alexander_Brown': 11,
#  'John_Kempe': 11,
#  'Mr._Bell': 9,
#  'Mr_Maidstone': 9,
#  'Mr_Cooke': 9,
#  'Robert_Hooke': 8,
#  'Mr_Maidstone, Mr._Maidstone': 8,
#  'John_Conyers': 8,
#  'Dr._Kempfer': 8,
#  'William_Courten': 7,
#  'Richard_Middleton_Massey': 7,
#  'D_Woodward': 7,
#  'Thomas_Murray': 7,
#  'Mr._Cowper': 6,
#  'Mr_Dupuys': 6,
#  'Guilllaume_Toulouze': 6,
#  'Jean_De_Fontaney': 5,
#  'James_Wilson': 5,
#  'Patrick_Adair': 5,
#  'Martin_Lister': 5,
#  'John_Covel': 5,
#  'John_Ranby': 5,
#  'Abbe_Bernardo_Sterbini': 5,
#  'John_Winthrop': 5,
#  'John_Morton': 5,
#  'Oliver_Cromwell': 5,
#  'Mrs._Merian': 5,
#  'Charles_I': 5,
#  'Mr._Marlow': 5,
#  'Alexander_Stuart': 4,
#  'James_Cunningham': 4,
#  'George_Edwards, Mr._Edwards': 4,
#  'John_Pinfold': 4,
#  'Gilbert_Heathcote': 4,
#  'Johann_Georg_Steigertahl': 4,
#  'Elihu_Yale': 4,
#  'Abraham_Cyprianus': 4,
#  'Mr._Dering': 4,
#  'Thomas_Short': 4,
#  'James_Theobalds_Esqr': 3,
#  'Mr_Roberts': 3,
#  'Mrs_Hayes': 3,
#  'King3': 3,
#  'Ambrose_Godfrey-Hanckwitz': 3,
#  'Jean_Rodoplhe_Lavater, Dr._Lavater': 3,
#  'Thomas_Simon': 3,
#  'Mr_Van_Mildert': 3,
#  'JohnFul': 3,
#  'Roger_Gale': 3,
#  'Mr._Clerk': 3,
#  'Mrs_Dering, Mrs._Dering': 3,
#  'Queen_Elizabeth_I': 3,
#  'King_James': 3,
#  'Mr_Warner_': 3,
#  'Henry_ye_8th': 3,
#  'Albert_Durer': 3,
#  'Nicolas_Robert': 3,
#  'William_Faithorne': 3,
#  'Silvestre': 3,
#  'Hans_Holbein': 3,
#  'Mr._Butterfield': 3,
#  'MrMC': 2,
#  'Mr._Hodson': 2,
#  'Capt_Walker': 2,
#  'Peter_Collinson': 2,
#  'Mr._Gordon': 2,
#  'Dr_Douce': 2,
#  'Mr_Lapthorn': 2,
#  'Rene_Reaumur': 2,
#  'Mr._Marshall': 2,
#  'Frederick_Slare': 2,
#  'Robert_Boyle': 2,
#  'Pierre_Silvestre': 2,
#  'Dampier': 2,
#  'Duke_Marlborough': 2,
#  'Hoffsted_van_Essen': 2,
#  'Mr_Hodges': 2,
#  'Joy': 2,
#  'Thomas_Tennison': 2,
#  'Caspar_Antonio': 2,
#  'Claude_Geoffroy1': 2,
#  'Charles_Cadogan': 2,
#  'Dr_Bokelman': 2,
#  'HenrySr.': 2,
#  'George_I': 2,
#  'Benjamin_Franklin': 2,
#  'Francis_Nicholson': 2,
#  'Robert_Houston': 2,
#  'Mr_Elking': 2,
#  'Mrs_Shepherd': 2,
#  'Mr_Purnell': 2,
#  'Charles_Lennox_Duke_of_Richmond, James_Stuart_Duke_of_Richmond': 2,
#  'Nehemiah_Grew': 2,
#  'Mr_Green': 2,
#  'Mr_Gilbert': 2,
#  'Mr._Laurie': 2,
#  'Mr_Seguier': 2,
#  'Dr_Huntington': 2,
#  'Mr._Compton': 2,
#  'Richard_Richardson': 2,
#  'Thomas_Browne': 2,
#  'Oldisworth': 2,
#  'Adrian_Beverland': 2,
#  'William_Stukely': 2,
#  'Mr._Nadler': 2,
#  'Mr_Leneve': 2,
#  'King_James_2nd': 2,
#  'Sir_Richard_Steele': 2,
#  'David_Loggan': 2,
#  'Mr._Doyly': 2,
#  'Mrs_Fuller': 2,
#  'Jeremiah_Taverner': 2,
#  'Mr._Sam._Langley': 2,
#  'Van_Dyck': 2,
#  'Miller': 2,
#  'Mr._Hughs': 2,
#  'Anna_Maria_van_Schurman': 2,
#  'John_Oliver': 2,
#  'Charles_II': 2,
#  'Valerius_Bellus': 2,
#  'Jacques_Callot': 2,
#  'Queen_Catherine': 2,
#  'Dr._Rugeley': 2,
#  'Sr_Godfrey_Kneller': 2,
#  'Christophe_Albemarle': 2,
#  'Mr._Amyand': 1,
#  'Mr._Launce': 1,
#  'Isaac_Waldron_Esqr': 1,
#  'Abraham_Waldron': 1,
#  'Matthew_Gosset': 1,
#  'Duke_of_Bourbon': 1,
#  'Mrs_Edwards, Mrs._Edwards': 1,
#  'Lady_Sondes': 1,
#  'Mr_Styleman': 1,
#  'Capt_Christopher_Middleton': 1,
#  'Mr_Hoofnail': 1,
#  'Mrs_Hepheshebah_Parker': 1,
#  'Dr_Labe': 1,
#  'Mrs_Stephens': 1,
#  'Mr._Pycolas': 1,
#  'Moses': 1,
#  'Mr_Collier': 1,
#  'Mrs_Bernard': 1,
#  'Mr_Doyly': 1,
#  'Mr._Bewley': 1,
#  'Francois_Duquesnoy': 1,
#  'Mr._Beddevoles': 1,
#  'John_Melling': 1,
#  'Johannes_van_Musschenbroek': 1,
#  'Mr_Desmarets': 1,
#  'Francis_Hauksbee': 1,
#  'Arthur_Charlett': 1,
#  'Giuseppe_Campani': 1,
#  'Mr_Lenoy': 1,
#  'Stephen_Gray': 1,
#  'Gio_Bapt_Verle': 1,
#  'Mr_Villarmont': 1,
#  'William_von_Schroder': 1,
#  'Robert_Moray': 1,
#  'Lord_Colerane': 1,
#  'Monsr_Villette': 1,
#  'Mr._Staphorst': 1,
#  'Father_Visdelon': 1,
#  'Beauvilliers': 1,
#  'Lady_Kent': 1,
#  'Mr_Carmichael': 1,
#  'William_Sherard': 1,
#  'Charles_Leigh': 1,
#  'Charles_Montagu': 1,
#  'Mr_Robert_Walker': 1,
#  'Colonel_Laws': 1,
#  'Mrs_Sadler': 1,
#  'Mr_Orchard': 1,
#  'Edmund_Chishull': 1,
#  'Mr_Middleton': 1,
#  'Sir_Charles_Wager': 1,
#  'Richard_Mead': 1,
#  'Mrrown': 1,
#  'Dr_Browne': 1,
#  'George_Cheyne': 1,
#  'Dr_Groenfield': 1,
#  'Mr_James': 1,
#  'William_Dunker': 1,
#  'John_Rawdon': 1,
#  'Martha_Cooper': 1,
#  'Sr_Streynsham_Masters': 1,
#  'Duke_of_Monmouth': 1,
#  'Dr._Hobbs': 1,
#  'Mr._Homberg': 1,
#  'Mr._Robinson': 1,
#  'Mr_Burnett': 1,
#  'Francis_Aston': 1,
#  'Jean_Rodolphe_Perronet': 1,
#  'Mr_Gilberts': 1,
#  'William_Cowper2': 1,
#  'Robert_Harley': 1,
#  'Albertus_Seba': 1,
#  'Mrs._Trenchfield': 1,
#  'Mr._Moults': 1,
#  'Mr_Stallwood': 1,
#  'Mr_Johnson': 1,
#  'Mr._Ott': 1,
#  'Riley': 1,
#  'Mrs_Byde': 1,
#  'George_Harris': 1,
#  'Prince_of_Hesse': 1,
#  'John_Conduitt': 1,
#  'Baron_Botmar': 1,
#  'Mrs_Heathcote': 1,
#  'Mr._Serocold': 1,
#  'Mr_Harvey': 1,
#  'Mr._Hill': 1,
#  'Mrs_Astall': 1,
#  'Lady_Darlington': 1,
#  'Mark_Catesby': 1,
#  'Nicolas_Waites': 1,
#  'Mr._Campbell': 1,
#  'Baron_Rostgard': 1,
#  'Mr_Skinner': 1,
#  'Charles_Lockyer': 1,
#  'Dr_Hubbert': 1,
#  'Thomas_Pitt': 1,
#  'Mr._Harris': 1,
#  'Dr_Burnett': 1,
#  'Dr_Hoffman': 1,
#  'Henry_Plumptre': 1,
#  'Mr_John_Heathcote': 1,
#  'Governor_Bennet': 1,
#  'Dr_Varin': 1,
#  'Mr_Fabre': 1,
#  'Mr_Padmore': 1,
#  'Mr_Lyell': 1,
#  'Mr_Walduck': 1,
#  'Mr_Standish': 1,
#  'Mr._Barrets': 1,
#  'Robert_Southwell': 1,
#  'John_Thomas_Woolhouse': 1,
#  'Dr._Mausafia': 1,
#  'Dr_Battely': 1,
#  'Mr_Nichols': 1,
#  'Mrs_Steigertahl': 1,
#  'Paul_Lucas': 1,
#  'Mr._Wild': 1,
#  'Governr_Jennings': 1,
#  'Erik_Benzelius': 1,
#  'William_Houstoun': 1,
#  'Mr._Bradley': 1,
#  'Mr_Talbot': 1,
#  'Isaaci_Barrow': 1,
#  'Dr._Clifton': 1,
#  'Mr._Godfroy': 1,
#  'Mr._Graham': 1,
#  'Mr_Lascelles': 1,
#  'Mr._Kenly': 1,
#  'Henry_Newman': 1,
#  'Peirce_Dod': 1,
#  'Mrs_Marshall': 1,
#  'Mr_Nash': 1,
#  'Mr_Sainthill': 1,
#  'Revd_Mr_Scott': 1,
#  'Charles_Maitland': 1,
#  'FrancisBuccleuch': 1,
#  'Mr_Muhleman': 1,
#  'John_Winthrop, Mr._Winthorpe': 1,
#  'James_Hodgson': 1,
#  'Johann_Amman': 1,
#  'Capt_Jenkens': 1,
#  'Philip_Miller': 1,
#  'Mr._Mason': 1,
#  'Mr_Grubb': 1,
#  'Mr._Cox': 1,
#  'Johann_Jakob_Scheuchzer': 1,
#  'Mr_Charles_de_la_Fontaine': 1,
#  'Mr_Conyers': 1,
#  'Oldsworth': 1,
#  'Dr_John_Harwood, Dr_Harwood': 1,
#  'Mr._Martin': 1,
#  'Mr._Sandys': 1,
#  'Edward_Browne': 1,
#  'Mr_Lloyd': 1,
#  'Mr_Cairns': 1,
#  'Bp_of_Norwich': 1,
#  'Charles_Townshend': 1,
#  'Mr._Wainwright': 1,
#  'Jius': 1,
#  'Mr_Holiday': 1,
#  'Dr_Brooks': 1,
#  'William_Ellis': 1,
#  'Mr_Alexander_Gordon': 1,
#  'Mr_Kennedy': 1,
#  'Mr._Smith': 1,
#  'Lord_Burlington': 1,
#  'Andr_Hay': 1,
#  'Mr._Stanley': 1,
#  'Sr._John_Colbatch': 1,
#  'Mr_Hildesley': 1,
#  'Robert_Wood': 1,
#  'Mrs_Standish': 1,
#  'Lord_Pembroke': 1,
#  'Mr_George': 1,
#  'Soranzo': 1,
#  'Cromwell_Mortimer': 1,
#  'Dr._Rosse': 1,
#  'Mr_Jackson': 1,
#  'Francois_Louis_de_Bourbon': 1,
#  'William_Courtney': 1,
#  'Isaac_Newton': 1,
#  'Doge_Francesco_Morosini': 1,
#  'Louis_14th': 1,
#  'Duke_of_Bavaria': 1,
#  'Francis_Drake': 1,
#  'Sir_Edward_Nicholas': 1,
#  'T_Dackett': 1,
#  'Mrs._Pritchard': 1,
#  'Richard_Hooker': 1,
#  'Laurentius_Costerus': 1,
#  'Bernard_Lens_II': 1,
#  'Mr._Bizot': 1,
#  'Orlando_Bridgeman': 1,
#  'Mr._Petyt': 1,
#  'Du_Bosse': 1,
#  'George_Duke_Albemarle': 1,
#  'Della_Bella': 1,
#  'Margaret_Smith': 1,
#  'John_Caius': 1,
#  'Samuel_Pepys': 1,
#  ' James_Stanier': 1,
#  'Mrs._Johanna_Byron': 1,
#  'Barlow': 1,
#  'Mr._Jacob_Selo': 1,
#  'Alexander_Marshal': 1,
#  'William_Harvey': 1,
#  'Wissen': 1,
#  'Rossi': 1,
#  'Mrs_Courten': 1,
#  'John_Cecil_5th_Earl_of_Exeter': 1,
#  'Mrs._Anne_Rose': 1,
#  'Vesalius': 1,
#  'Antony_More': 1,
#  'Franciscus_Mercurius_van_Vanhelmont': 1,
#  'Joos_de_Momper': 1,
#  'Sr_Theodore_Mayern': 1,
#  'Philip_Rose, Fulke-Rose': 1,
#  'Mrs._Willoughby': 1,
#  'Peter_Paul_Rubens': 1,
#  'Polemburg': 1,
#  'Hans_Sloane': 1,
#  'Mrs_Sloane': 1,
#  'Ulisse_Aldrovandi': 1,
#  'Giorgione': 1,
#  'Mr_Cock': 1,
#  'Edmund_King': 1,
#  'Housman': 1,
#  'Mr_Kinsay': 1,
#  'HE': 1,
#  'Martin_Luther': 1,
#  'Earl_of_Arundell': 1,
#  'Thomas_Browne, Thomas_Browne': 1,
#  'Owen_Brigstocke': 1,
#  'George_Jeffreys': 1,
#  'Frere_Jaques': 1,
#  'Adriaen_Brouwer': 1,
#  'William_Dobson': 1,
#  'Hilliard': 1,
#  'Mr_Thornton': 1,
#  'Frederik_Ruysch': 1,
#  'Mrs_Aesop': 1,
#  'Francesco_Cornaro': 1,
#  'Frederich_Saxony': 1,
#  'Earl_of_Essex': 1,
#  'Jacomo_Poro': 1,
#  'Barbara_van_Beck': 1,
#  'Philip_2nd_of_Spain': 1,
#  'John_Oliver, Olivar': 1,
#  'Sir_Thomas_More': 1,
#  'John_Fisher': 1,
#  'Thomas_Gresham': 1,
#  'Abraham_Simon': 1,
#  ' Fielder_the_Vintner': 1,
#  'Giovanni_Maria_Lancisi': 1,
#  'Sebastiano_Concha': 1,
#  'Queen_Anne': 1,
#  'Mr._Dundasse': 1,
#  'George_II': 1,
#  'William_Duke_of_Gloucester': 1,
#  'Richard_Baker': 1,
#  'Moliere': 1,
#  'Pierre_Corneille': 1,
#  'Charles_Derby': 1,
#  'Jean_de_Labadie': 1,
#  'John_Fletcher': 1,
#  'Polidoro_di_Caravagio': 1,
#  'Mr._Simpson': 1,
#  'Lord_Archbishop_Dublin': 1,
#  'Frank_van_Borselen': 1,
#  'Philip_Wouwerman': 1,
#  'Tobias_Stranover': 1,
#  'Lord_Lynn': 1,
#  'Jan_van-Huysum': 1,
#  'Gilbert_Burnett': 1,
#  'Vanzoon': 1,
#  'Lord_Yarmouth': 1,
#  'J._Simmons': 1,
#  'Dr._Rugeley_father': 1,
#  'Mr_Jones': 1,
#  'Major_John_Hanbury': 1,
#  'Alexander_Geekie_senior': 1,
#  'Mrs_John_Hanbury': 1,
#  'Walter_Churchman': 1,
#  'Jacob_Theodor_Klein': 1,
#  'Guillaume_Dupre': 1,
#  'Godwin_Lewis': 1,
#  'Eustachio_de_divinis': 1,
#  'Charles_Scarburgh': 1,
#  'Edward_Baynard': 1,
#  'Colonel_Wharton': 1,
#  'Henry_Wynne': 1,
#  'Johann_Ernst_Galliard': 1,
#  'William_Nicholson': 1,
#  'Mr._Thomas': 1,
#  'Mr_Vanhulse': 1,
#  'Mr._Tinsey': 1,
#  'Madam_Montmorency': 1}

# %%
# to find out number of instances of names (including multiple names in a row.) This will contain duplicates
res = []
for x in names:
    first =
    n = eval(x)
    if n:
        for i in n:
            
            print(i.strip('#'))
            res.append(i.strip('#'))
len(res)
