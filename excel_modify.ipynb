# %%
from openpyxl import Workbook

# %%
wb_list = load_workbook(filename = 'empty_book.xlsx')

# %%
ref = load_workbook(filename = 'empty_book.xlsx')

# %%
import csv

# %%
with open('result.csv', newline='') as csvfile:
    r = csv.reader(csvfile, delimiter=' ', quotechar='|')
    counter = 0
    for row in r:
        s = ', '.join(row)
        if counter == 0:
            match = xd
#             print('match=' + match)
        if counter == 1:
            if 'SLMisc' in s and match == '1':
                interested = True
                name = s.split(',')[0]
                print('Found: ' + s + 'Match = ' + match)
        if interested:
            
            res[name] = 
#         print(s)
        counter +=1
        if s.startswith('---'):
            interested = False
            counter = 0
# Out:
# Found: "Af,SLMisc.1830.a-b",EAF57,1830Match = 1
# Found: SLMisc.1837.a-b,JCR5120,1837Match = 1
# Found: "Am,SLMisc.1842",ENA219,1842Match = 1
# Found: SLMisc.1866,RRC3782,1866Match = 1
# Found: SLMisc.1879,MCM6334,1879Match = 1
# Found: "Am,SLMisc.1933",ENA220,1933Match = 1
# Found: "Am,SLMisc.1934",ENA221,1934Match = 1
# Found: "Af,SLMisc.1935",EAF28963,1935Match = 1
# Found: "As,SLMisc.145",EAS126,145Match = 1
# Found: SLMisc.1984,MCN3631,1984Match = 1
# Found: SLMisc.1985,MCN3638,1985Match = 1
# Found: SLMisc.1987,MCN7742,1987Match = 1
# Found: SLMisc.2010,MCN7779,2010Match = 1
# Found: "Am,SLMisc.2089",ENA225,2089Match = 1
# Found: SLMisc.2101,MCN13015,2101Match = 1
# Found: SLMisc.2102,MCN7765,2102Match = 1
# Found: "Af,SLMisc.2105",EAF60645,2105Match = 1
# Found: SLMisc.342,RRM2,342Match = 1
# Found: "Eu,SLMisc.401",EEU1,401Match = 1
# Found: SLMisc.418,RRC3753,418Match = 1
# Found: "Af,SLMisc.424",EAF28961,424Match = 1
# Found: SLMisc.562,RRC3754,562Match = 1
# ...
