# %%
from openpyxl import load_workbook
workbook = load_workbook(filename='/Users/deborahleem/sloane_db_list_modified.xlsx')

# %%
print(workbook.sheetnames)
print(sheet.title)
# Out:
# ['objects']
# objects

# %%
print(sheet['A1'])
print(sheet['A1'].value)
# Out:
# <Cell 'objects'.A1>
# Matched

# %%
#get all data from a column
for i in sheet['B']:
    print(i.value)
# Out:
# Reg No.
# None
# None
# .129
# .161
# .167
# .173
# .245
# .248
# .249
# .254
# .255
# .258
# .260
# .263
# .264
# .265
# .267
# .279
# .304
# .343
# .352
# .353
# .354
# .355
# .356
# .357
# .358
# .359
# .407
# .437
# .445
# .446
# .448
# .449
# .454
# .455
# .456
# .457
# .458
# .459
# .460
# .461
# .462
# .463
# .464
# .465
# .466
# .467
# .468
# .488
# .511
# .565
# .592
# .593
# .635
# .636
# .761
# .886
# .990
# .1001
# .1007
# .1008
# .1011
# .1014
# .1015
# .1016
# .1037
# .2123
# .2124
# .2125
# .8962
# .9039
# .9045
# .9100
# .9101
# .9102
# .9159
# .9194
# .11192
# .15087
# .60411
# .60580
# .60602
# .60755
# .61009
# .61305
# 1756,0101.18
# 1756,0101.20
# 1756,0101.22
# 1756,0101.25
# 1756,0101.36
# 1756,0101.81
# 1756,0101.106
# 1756,0101.119
# 1756,0101.120
# 1756,0101.121
# 1756,0101.164
# 1756,0101.190.1
# 1756,0101.195
# 1756,0101.196
# 1756,0101.197
# 1756,0101.198
# 1756,0101.199
# 1756,0101.200
# 1756,0101.203
# 1756,0101.204
# 1756,0101.208
# 1756,0101.218
# ...
